# %% [markdown]
# # Test Notebook

# %% [markdown]
# This is a test notebook for checking rendering on GitHub.

# %%
import numpy as np
import matplotlib.pyplot as plt

y = np.array([0, 5, 2, 8, 1])

plt.figure()
plt.plot (y)
plt.show()

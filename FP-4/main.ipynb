# %%
from parse_data import load_finaldata
import descriptive

# %%
finaldata = load_finaldata()
finaldata.head()
# Out:
#                Country  Year  ISO  Population  Electricity demand  \
# 1              Albania  2021  ALB   2849591.0                8.39
# 2              Algeria  2021  DZA  44761051.0               84.45
# 3       American Samoa  2021  ASM     49202.0                0.17
# 4               Angola  2021  AGO  34532382.0               16.85
# 5  Antigua and Barbuda  2021  ATG     92316.0                0.35
#
#    GHG emissions  FF electricity share  RE electricity share Income Group FY23
# 1           0.21                 0.000               100.000                UM
# 2          54.23                99.054                 0.946                LM
# 3           0.11               100.000                 0.000                UM
# 4           2.91                24.570                75.430                LM
# 5           0.22                94.286                 5.714                 H

# %%
descriptive.run_all(finaldata)
# Out:
# <br><br><p><span style='font-size: 1.2em;'><b>Table 1</b>: Central tendency summary statistics.</span></p>
#         Population  Electricity demand  GHG emissions  FF electricity share  \
# mean    39207284.0              140.18          69.46                 60.99
# median   7484547.0               11.73           2.77                 67.13
# mode       11687.0                0.17           0.07                100.00
#
#         RE electricity share
# mean                   35.44
# median                 24.18
# mode                    0.00
# <br><br><p><span style='font-size: 1.2em;'><b>Table 2</b>: Dispersion summary statistics.</span></p>
#            Population  Electricity demand  GHG emissions  \
# st.dev.  1.468222e+08              688.68         392.92
# min      1.168700e+04                0.04           0.00
# max      1.426437e+09             8520.02        5112.06
# range    1.426426e+09             8519.98        5112.06
# ...
